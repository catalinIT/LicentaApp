# %%
import pandas as pd

cleaned_balanced_df = pd.read_csv("politifact_balanced_data.csv")

# %%
print(len(cleaned_balanced_df))
# Out:
# 2165

# %% [markdown]
# # Study the lenght of the recorded variables

# %%
cleaned_balanced_df["length"] = cleaned_balanced_df.statement.str.len()

# %%
cleaned_balanced_df.describe()
# Out:
#          Unnamed: 0     veracity         freq       length
# count   2165.000000  2165.000000  2165.000000  2165.000000
# mean    5188.898845     0.494226     1.787067   107.792610
# std     3195.945681     0.500082     1.010764    46.179039
# min        3.000000     0.000000     1.000000    20.000000
# 25%     2288.000000     0.000000     1.000000    75.000000
# 50%     5032.000000     0.000000     1.000000   100.000000
# 75%     8082.000000     1.000000     2.000000   133.000000
# max    11183.000000     1.000000     4.000000   400.000000

# %%
cleaned_balanced_df[cleaned_balanced_df.length > 250][:100]
# Out:
#       Unnamed: 0                                          statement  \
# 68           199  "Ninety percent of people born in the 1940s en...
# 77           223  "In the eight years that I was mayor, (there w...
# 99           317  "Facts have come to light that indicate that a...
# 194          689  "When I became mayor of Los Angeles, we had a ...
# 259          939  "Local authorities in 43 states refused to hon...
# 278         1023  "From the release of a child rapist from the D...
# 360         1374  "If you give guns to gangs, you can get out of...
# 363         1383  "It’s bad enough that (Stephen) Silberkraus ap...
# 402         1601  "Because there's no local option to allow comm...
# 418         1653  "Illinois suffered 1,652 overdose deaths in 20...
# 419         1655  "Then, the Republican leader theatrically intr...
# 512         2156  "After taking hundreds of thousands of dollars...
# 720         3420  "Every year in the United States between 3,000...
# 794         3787  "[When I was mayor] Providence was one of the ...
# 1000        4750  "What do Rutgers University, Kean University, ...
# 1139        5353  "People want the minimum wage, they want marri...
# 1156        5410  "Barbara Buono by the numbers: As a Trenton po...
# 1187        5572  "Under Republican Chris Christie, New Jersey h...
# 1213        5693  "There's a tax credit of $2,400 to bond [forme...
# 1264        5917  "Right now one of our highest job growth secto...
# 1503        7382  "In 1790, the first Congress, which was packed...
# 1562        7736  "The Tax Foundation figures Rhode Island as th...
# 1983        9728  "Powerful Houston  Democrats Sylvia Garcia (De...
# 2024        9922  "Obama did not open new lands to offshore dril...
# 2138       10761  "The legislation ... that Senator McCain suppo...
#
#                                              source  \
# 68                                   Delaine Eastin
# 77                            Antonio  Villaraigosa
# 99                                      Kris Kobach
# 194                           Antonio  Villaraigosa
# 259                                     Steve Adler
# 278                                    Joe DeFelice
# 360                                 Loretta Sanchez
# 363                                    Lesley Cohen
# 402                                    Vote No On 2
# 418                                  Richard Durbin
# 419                                   Kelly Cassidy
# 512                                      Tim Canova
# 720                                       Bob Sears
# 794                          Vincent "Buddy" Cianci
# 1000                                   Joseph Cryan
# 1139                                Stephen Sweeney
# 1156               Republican Governors Association
# 1187                                 One New Jersey
# 1213                               Carolyn Medeiros
# 1264                                  Lou Greenwald
# 1503                                  Einer Elhauge
# 1562                                 Peter  Palumbo
# 1983                                   David Barton
# 2024  House Natural Resources Committee Republicans
# 2138                                       Bob Barr
#
#                                                    link  veracity  freq  \
# 68    /web/20180119164739/http://www.politifact.com/...         1     1
# 77    /web/20180119165429/http://www.politifact.com/...         1     4
# 99    /web/20180119170716/http://www.politifact.com/...         0     1
# 194   /web/20180119171252/http://www.politifact.com/...         1     4
# 259   /web/20180119171447/http://www.politifact.com/...         1     4
# 278   /web/20180119171520/http://www.politifact.com/...         0     1
# 360   /web/20180119171703/http://www.politifact.com/...         0     2
# 363   /web/20180119171707/http://www.politifact.com/...         0     1
# 402   /web/20180119171753/http://www.politifact.com/...         0     1
# 418   /web/20180119171804/http://www.politifact.com/...         1     3
# 419   /web/20180119171804/http://www.politifact.com/...         0     1
# 512   /web/20180119171936/http://www.politifact.com/...         1     1
# 720   /web/20180119172310/http://www.politifact.com/...         0     1
# 794   /web/20180119172403/http://www.politifact.com/...         1     3
# 1000  /web/20180119172713/http://www.politifact.com/...         1     1
# 1139  /web/20180119173042/http://www.politifact.com/...         1     2
# 1156  /web/20180119173105/http://www.politifact.com/...         1     4
# 1187  /web/20180119173241/http://www.politifact.com/...         1     2
# 1213  /web/20180119173343/http://www.politifact.com/...         0     1
# 1264  /web/20180119173430/http://www.politifact.com/...         1     3
# 1503  /web/20180119174201/http://www.politifact.com/...         1     1
# 1562  /web/20180119174506/http://www.politifact.com/...         0     3
# 1983  /web/20180119175750/http://www.politifact.com/...         0     1
# 2024  /web/20180119175938/http://www.politifact.com/...         0     1
# 2138  /web/20180119180457/http://www.politifact.com/...         1     1
#
#       length
# 68       292
# 77       308
# 99       257
# 194      318
# 259      290
# 278      273
# 360      256
# 363      285
# 402      289
# 418      291
# 419      261
# 512      264
# 720      270
# 794      295
# 1000     254
# 1139     316
# 1156     400
# 1187     292
# 1213     301
# 1264     373
# 1503     298
# 1562     251
# 1983     292
# 2024     260
# 2138     271

# %% [markdown]
# # Analyze the data

# %%
import numpy as np
import os
import csv 

# for EDA
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline   
from collections import Counter

# for NLP
from textatistic import Textatistic
import spacy
from spacy import displacy

# for Statistics
from scipy import stats

# %%
# Obs.after preprocessing, the text is quite balanced out
cleaned_balanced_df.veracity.value_counts()
# Out:
# 0    1095
# 1    1070
# Name: veracity, dtype: int64

# %% [markdown]
# # Preprocessing Steps: Creating a condensed (lemmatized) text

# %%
nlp = spacy.load('en_core_web_md')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 nlp = spacy.load('en_core_web_md')
#
# File C:\Python\Python39\lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, exclude, config)
#      30 def load(
#      31     name: Union[str, Path],
#      32     *,
#    (...)
#      36     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      37 ) -> Language:
#      38     """Load a spaCy model from an installed package or a local path.
#      39
#      40     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# File C:\Python\Python39\lib\site-packages\spacy\util.py:427, in load_model(name, vocab, disable, exclude, config)
#     425 if name in OLD_MODEL_SHORTCUTS:
#     426     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_md'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
# lemmatization function
def lemmatize(text):
    # create nlp object
    nobj = nlp(text)
    
    # stopword list from spacy
    stopwords = spacy.lang.en.stop_words.STOP_WORDS
    
    # simple lemmas
    lemmas = [token.lemma_ for token in nobj]
    
    # lowercase; remove non-alphabetic characters & overly used words, i.e., stop words
    a_lemmas = [lemma.lower() for lemma in lemmas
                if lemma.isalpha() 
                and lemma not in stopwords]
    
    # strings
    strings = " ".join(a_lemmas)
    
    return strings

# %%
# sample: removes whitespaces, puncuation, stopwords, special characters; converts to lowercase
lemmatize(" ! i don't, won't,   can't not use    NLP 27x maaaah?")
# Out:
# 'i use nlp maaaah'

# %%
cleaned_balanced_df["lemmas"] = cleaned_balanced_df.statement.apply(lemmatize)

# %%
cleaned_balanced_df[500:1500:500]
# Out:
#       Unnamed: 0                                          statement  \
# 500         2088  "The city of Charlotte passed a bathroom ordin...
# 1000        4750  "What do Rutgers University, Kean University, ...
#
#             source                                               link  \
# 500    Pat McCrory  /web/20180119171924/http://www.politifact.com/...
# 1000  Joseph Cryan  /web/20180119172713/http://www.politifact.com/...
#
#       veracity  freq  length  \
# 500          0     3     106
# 1000         1     1     254
#
#                                                  lemmas
# 500   city charlotte pass bathroom ordinance mandate...
# 1000  rutgers university kean university montclair s...

# %% [markdown]
# # Tagging Text

# %% [markdown]
# # Part of Speech (POS) Tagging

# %% [markdown]
# ## .pos_ (general pos tagging -- 16 tags)

# %%
# .pos_ example
nobj = nlp(cleaned_balanced_df.statement[21])
pos = [(token.text, token.pos_) for token in nobj]
print(pos)
# Out:
# [('"', 'PUNCT'), ('The', 'DET'), ('graduation', 'NOUN'), ('rate', 'NOUN'), ('in', 'ADP'), ('New', 'PROPN'), ('York', 'PROPN'), ('City', 'PROPN'), ('has', 'AUX'), ('increased', 'VERB'), ('by', 'ADP'), ('50', 'NUM'), ('percent', 'NOUN'), ('in', 'ADP'), ('13', 'NUM'), ('years', 'NOUN'), ('"', 'PUNCT')]

# %%
def dot_pos_tagger(text):
    # nlp object
    nobj = nlp(text)
    # POS tags
    tagged_text = [(token.text, token.pos_) for token in nobj]
    # tagged text
    return tagged_text

cleaned_balanced_df["general_pos_tags"] = cleaned_balanced_df.statement.apply(dot_pos_tagger)

# %%
cleaned_balanced_df[["general_pos_tags"]][0:2]
# Out:
#                                     general_pos_tags
# 0  [(", PUNCT), (Tim, PROPN), (Kaine, PROPN), (do...
# 1  [(", PUNCT), (The, DET), (deficit, NOUN), (......

# %%
# a more visual rendering of the above
displacy.render(nobj, 
                style = "dep", # styles are dep (dependency) or ent (entity)
                jupyter = True,
                options = {
                          "distance" : 125,
                          "arrow_stroke" : 2, # thickness of arrow line
                          "arrow_width" : 8, # thickness of arrow head
                          "bg" : "#EDEDED" # background color
                         })
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="73e63a7ac89c45c7aa7a521cb952c1cf-0" class="displacy" width="2050" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #EDEDED; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="175">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="175">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">graduation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="425">rate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="675">New</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">York</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">City</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1175">increased</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1175">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1300">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1425">50</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1425">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">percent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1675">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">13</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1925">years&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-0" stroke-width="2px" d="M70,377.0 C70,2.0 1175.0,2.0 1175.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,379.0 L64,369.0 76,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-1" stroke-width="2px" d="M195,377.0 C195,252.0 405.0,252.0 405.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M195,379.0 L189,369.0 201,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-2" stroke-width="2px" d="M320,377.0 C320,314.5 400.0,314.5 400.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320,379.0 L314,369.0 326,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-3" stroke-width="2px" d="M445,377.0 C445,64.5 1170.0,64.5 1170.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445,379.0 L439,369.0 451,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-4" stroke-width="2px" d="M445,377.0 C445,314.5 525.0,314.5 525.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,379.0 L531.0,369.0 519.0,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-5" stroke-width="2px" d="M695,377.0 C695,314.5 775.0,314.5 775.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M695,379.0 L689,369.0 701,369.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-73e63a7ac89c45c7aa7a521cb952c1cf-0-6" stroke-width="2px" d="M820,377.0 C820,314.5 900.0,314.5 900.0,377.0" fill="none" stroke="currentColor"/>
#     <text dy="

# %% [markdown]
# ## .tag_ (specific pos tagging -- 53 tags)

# %%
# .tag_ example (more specific pos tagging)
nobj = nlp(cleaned_balanced_df.statement[21])
pos = [(token.text, token.tag_) for token in nobj]
print(pos)
# Out:
# [('"', '``'), ('The', 'DT'), ('graduation', 'NN'), ('rate', 'NN'), ('in', 'IN'), ('New', 'NNP'), ('York', 'NNP'), ('City', 'NNP'), ('has', 'VBZ'), ('increased', 'VBN'), ('by', 'IN'), ('50', 'CD'), ('percent', 'NN'), ('in', 'IN'), ('13', 'CD'), ('years', 'NNS'), ('"', "''")]

# %%
def dot_tag_tagger(text):
    # nlp object
    nobj = nlp(text)
    # tags
    tagged_text = [(token.text, token.tag_) for token in nobj]
    # tagged text
    return tagged_text

cleaned_balanced_df["specific_pos_tags"] = cleaned_balanced_df.statement.apply(dot_tag_tagger)

# %%
cleaned_balanced_df[["specific_pos_tags"]][0:2]
# Out:
#                                    specific_pos_tags
# 0  [(", ``), (Tim, NNP), (Kaine, NNP), (does, VBZ...
# 1  [(", ``), (The, DT), (deficit, NN), (..., :), ...

# %% [markdown]
# ## SD (Syntatic Dependency) tagging

# %%
# .tag_ example (more specific pos tagging)
nobj = nlp(cleaned_balanced_df.statement[21])
sd = [(token.text, token.dep_) for token in nobj]
print(sd)
# Out:
# [('"', 'punct'), ('The', 'det'), ('graduation', 'compound'), ('rate', 'nsubj'), ('in', 'prep'), ('New', 'compound'), ('York', 'compound'), ('City', 'pobj'), ('has', 'aux'), ('increased', 'ROOT'), ('by', 'prep'), ('50', 'nummod'), ('percent', 'pobj'), ('in', 'prep'), ('13', 'nummod'), ('years', 'pobj'), ('"', 'punct')]

# %%
# sd function
def sd_tagger(text):
    # nlp object
    nobj = nlp(text)
    # tags
    tagged_text = [(token.text, token.dep_) for token in nobj]
    # tagged text
    return tagged_text

cleaned_balanced_df["sd_tags"] = cleaned_balanced_df.statement.apply(sd_tagger)

# %%
cleaned_balanced_df[["sd_tags"]][0:2]
# Out:
#                                              sd_tags
# 0  [(", punct), (Tim, compound), (Kaine, nsubj), ...
# 1  [(", punct), (The, det), (deficit, nsubj), (.....

# %%
cleaned_balanced_df.to_csv("ready_to_be_engineered.csv")
